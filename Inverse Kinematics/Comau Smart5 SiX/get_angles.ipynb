# %%
from IKM import *

# %% [markdown]
# ### Poses desejadas:

# %%
HOME = [
    [0, 0, 1, 892.07],
    [0, 1, 0, 0],
    [-1, 0, 0, 1170],
    [0, 0, 0, 1]
]

CALLSYS = [
    [1, 0, 0, 20],
    [0, 1, 0, 0],
    [0, 0, 1, 1782.07],
    [0, 0, 0, 1]
]

T1 = [
    [0, -1, 0, 0],
    [1, 0, 0, 797.07],
    [0, 0, 1, 1265],
    [0, 0, 0, 1]
]

T2 = [
    [-1, 0, 0, 797.07],
    [0, 1, 0, 0],
    [0, 0, -1, 1075],
    [0, 0, 0, 1]
]

# %%
angles = getAngles(T2)
for i in range(len(angles)):
    print(f'\t Theta {i+1} \t = \t {np.degrees(angles[i]):,.3f}')
# Out:
# 	 Theta 1 	 = 	 -0.000
# 	 Theta 2 	 = 	 0.000
# 	 Theta 3 	 = 	 -90.000
# 	 Theta 4 	 = 	 -180.000
# 	 Theta 5 	 = 	 -90.000
# 	 Theta 6 	 = 	 180.000
